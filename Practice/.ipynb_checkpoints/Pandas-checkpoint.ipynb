# %% [markdown]
# ## import and load data

# %%
import pandas as pd

# %%
# Load a CSV file
df = pd.read_csv("asset/data.csv")

# %%
# Show first few rows
df.head()
# Out:
#    x_position  y_position  composition_ratio  potential_V  \
# 0           1           1              0.800        0.986
# 1           1           2              0.817        0.572
# 2           1           3              0.833        0.987
# 3           1           4              0.850        0.779
# 4           1           5              0.867        1.075
#
#    current_density_mAcm2  raman_intensity_a.u.  contact_angle_deg
# 0                  3.767                 878.1               62.4
# 1                  2.358                 934.7               56.1
# 2                  1.272                 946.5               58.9
# 3                  4.341                 916.1               56.0
# 4                  2.963                 938.1               59.4

# %% [markdown]
# ## Basic Info About Data

# %%
df.shape 
# (rows, columns)
# Out:
# (25, 7)

# %%
df.columns 
# column names
# Out:
# Index(['x_position', 'y_position', 'composition_ratio', 'potential_V',
#        'current_density_mAcm2', 'raman_intensity_a.u.', 'contact_angle_deg'],
#       dtype='object')

# %%
df.info() 
# data types and non-null counts
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   x_position             25 non-null     int64
#  1   y_position             25 non-null     int64
#  2   composition_ratio      25 non-null     float64
#  3   potential_V            25 non-null     float64
#  4   current_density_mAcm2  25 non-null     float64
#  5   raman_intensity_a.u.   25 non-null     float64
#  6   contact_angle_deg      25 non-null     float64
# dtypes: float64(5), int64(2)
# memory usage: 1.5 KB

# %%
df.describe()
# quick statistics summary
# Out:
#        x_position  y_position  composition_ratio  potential_V  \
# count   25.000000   25.000000          25.000000    25.000000
# mean     3.000000    3.000000           1.000000     0.711000
# std      1.443376    1.443376           0.122649     0.310907
# min      1.000000    1.000000           0.800000     0.066000
# 25%      2.000000    2.000000           0.900000     0.540000
# 50%      3.000000    3.000000           1.000000     0.779000
# 75%      4.000000    4.000000           1.100000     0.940000
# max      5.000000    5.000000           1.200000     1.170000
#
#        current_density_mAcm2  raman_intensity_a.u.  contact_angle_deg
# count              25.000000              25.00000          25.000000
# mean                2.815640            1014.29600          59.920000
# std                 1.360656              77.63006           2.596472
# min                 0.156000             878.10000          54.500000
# ...

# %% [markdown]
# ## Selecting Data

# %%
df['potential_V']
# Out:
# 0     0.986
# 1     0.572
# 2     0.987
# 3     0.779
# 4     1.075
# 5     0.762
# 6     0.262
# 7     0.858
# 8     0.366
# 9     0.842
# 10    0.912
# 11    0.066
# 12    1.170
# 13    0.732
# 14    0.540
# 15    0.815
# 16    0.285
# 17    0.859
# 18    0.578
# 19    1.083
# 20    0.750
# 21    0.940
# 22    0.992
# 23    0.080
# 24    0.484
# Name: potential_V, dtype: float64

# %%
df[['potential_V', 'x_position']]
# Out:
#     potential_V  x_position
# 0         0.986           1
# 1         0.572           1
# 2         0.987           1
# 3         0.779           1
# 4         1.075           1
# 5         0.762           2
# 6         0.262           2
# 7         0.858           2
# 8         0.366           2
# 9         0.842           2
# 10        0.912           3
# 11        0.066           3
# 12        1.170           3
# 13        0.732           3
# 14        0.540           3
# 15        0.815           4
# 16        0.285           4
# 17        0.859           4
# 18        0.578           4
# 19        1.083           4
# 20        0.750           5
# 21        0.940           5
# 22        0.992           5
# 23        0.080           5
# 24        0.484           5

# %%
df.iloc[0]
# first row
# Out:
# x_position                 1.000
# y_position                 1.000
# composition_ratio          0.800
# potential_V                0.986
# current_density_mAcm2      3.767
# raman_intensity_a.u.     878.100
# contact_angle_deg         62.400
# Name: 0, dtype: float64

# %%
df.iloc[0:5]
# first five rows
# Out:
#    x_position  y_position  composition_ratio  potential_V  \
# 0           1           1              0.800        0.986
# 1           1           2              0.817        0.572
# 2           1           3              0.833        0.987
# 3           1           4              0.850        0.779
# 4           1           5              0.867        1.075
#
#    current_density_mAcm2  raman_intensity_a.u.  contact_angle_deg
# 0                  3.767                 878.1               62.4
# 1                  2.358                 934.7               56.1
# 2                  1.272                 946.5               58.9
# 3                  4.341                 916.1               56.0
# 4                  2.963                 938.1               59.4

# %% [markdown]
# ## Filtering / Conditional Selection

# %%
df[df['potential_V'] > 0.7]
# Out:
#     x_position  y_position  composition_ratio  potential_V  \
# 0            1           1              0.800        0.986
# 2            1           3              0.833        0.987
# 3            1           4              0.850        0.779
# 4            1           5              0.867        1.075
# 5            2           1              0.883        0.762
# 7            2           3              0.917        0.858
# 9            2           5              0.950        0.842
# 10           3           1              0.967        0.912
# 12           3           3              1.000        1.170
# 13           3           4              1.017        0.732
# 15           4           1              1.050        0.815
# 17           4           3              1.083        0.859
# 19           4           5              1.117        1.083
# 20           5           1              1.133        0.750
# 21           5           2              1.150        0.940
# ...

# %%
df[(df['x_position'] > 2) & (df['potential_V'] < 1.0)]
# Out:
#     x_position  y_position  composition_ratio  potential_V  \
# 10           3           1              0.967        0.912
# 11           3           2              0.983        0.066
# 13           3           4              1.017        0.732
# 14           3           5              1.033        0.540
# 15           4           1              1.050        0.815
# 16           4           2              1.067        0.285
# 17           4           3              1.083        0.859
# 18           4           4              1.100        0.578
# 20           5           1              1.133        0.750
# 21           5           2              1.150        0.940
# 22           5           3              1.167        0.992
# 23           5           4              1.183        0.080
# 24           5           5              1.200        0.484
#
#     current_density_mAcm2  raman_intensity_a.u.  contact_angle_deg
# 10                  1.438                1005.7               57.1
# ...

# %% [markdown]
# ## Basic Analysis

# %%
df['x_position'].mean()
# Out:
# np.float64(3.0)

# %%
df['x_position'].std()
# Out:
# 1.4433756729740645

# %%
df.corr()
# correlation between all numerical columns
# Out:
#                        x_position  y_position  composition_ratio  potential_V  \
# x_position               1.000000    0.000000           0.980542    -0.164901
# y_position               0.000000    1.000000           0.196297     0.000743
# composition_ratio        0.980542    0.196297           1.000000    -0.160808
# potential_V             -0.164901    0.000743          -0.160808     1.000000
# current_density_mAcm2   -0.060805    0.343358           0.007544     0.086145
# raman_intensity_a.u.     0.896517    0.215716           0.921157    -0.109842
# contact_angle_deg        0.353552   -0.086720           0.329810     0.225877
#
#                        current_density_mAcm2  raman_intensity_a.u.  \
# x_position                         -0.060805              0.896517
# y_position                          0.343358              0.215716
# composition_ratio                   0.007544              0.921157
# potential_V                         0.086145             -0.109842
# ...

# %% [markdown]
# ## Add / Modify Columns

# %%
import numpy as np
df['log_potential_v'] = np.log(df['potential_V'])
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df.head()
# Out:
#    x_position  y_position  composition_ratio  potential_V  \
# 0           1           1              0.800        0.986
# 1           1           2              0.817        0.572
# 2           1           3              0.833        0.987
# 3           1           4              0.850        0.779
# 4           1           5              0.867        1.075
#
#    current_density_mAcm2  raman_intensity_a.u.  contact_angle_deg  \
# 0                  3.767                 878.1               62.4
# 1                  2.358                 934.7               56.1
# 2                  1.272                 946.5               58.9
# 3                  4.341                 916.1               56.0
# 4                  2.963                 938.1               59.4
#
#    log_potential_v
# 0        -0.014099
# 1        -0.558616
# 2        -0.013085
# 3        -0.249744
# 4         0.072321

# %%
df['ratio'] = df['raman_intensity_a.u.'] / df['contact_angle_deg']

# %%
df.head()
# Out:
#    x_position  y_position  composition_ratio  potential_V  \
# 0           1           1              0.800        0.986
# 1           1           2              0.817        0.572
# 2           1           3              0.833        0.987
# 3           1           4              0.850        0.779
# 4           1           5              0.867        1.075
#
#    current_density_mAcm2  raman_intensity_a.u.  contact_angle_deg  \
# 0                  3.767                 878.1               62.4
# 1                  2.358                 934.7               56.1
# 2                  1.272                 946.5               58.9
# 3                  4.341                 916.1               56.0
# 4                  2.963                 938.1               59.4
#
#    log_potential_v      ratio
# 0        -0.014099  14.072115
# 1        -0.558616  16.661319
# 2        -0.013085  16.069610
# 3        -0.249744  16.358929
# 4         0.072321  15.792929

# %% [markdown]
# ## Handling Missing Data

# %%
df = pd.read_csv("asset/data.csv")

# %%
df.isnull().sum()
# count missing values
# Out:
# x_position               0
# y_position               0
# composition_ratio        1
# potential_V              1
# current_density_mAcm2    0
# raman_intensity_a.u.     0
# contact_angle_deg        0
# dtype: int64

# %%
df = df.dropna() 
# drop missing rows

# %%
df
# Out:
#     x_position  y_position  composition_ratio  potential_V  \
# 0            1           1              0.800        0.986
# 1            1           2              0.817        0.572
# 2            1           3              0.833        0.987
# 3            1           4              0.850        0.779
# 4            1           5              0.867        1.075
# 5            2           1              0.883        0.762
# 6            2           2              0.900        0.262
# 7            2           3              0.917        0.858
# 8            2           4              0.933        0.366
# 9            2           5              0.950        0.842
# 10           3           1              0.967        0.912
# 11           3           2              0.983        0.066
# 12           3           3              1.000        1.170
# 13           3           4              1.017        0.732
# 14           3           5              1.033        0.540
# ...

# %%
df.isnull().sum()
# Out:
# x_position               0
# y_position               0
# composition_ratio        0
# potential_V              0
# current_density_mAcm2    0
# raman_intensity_a.u.     0
# contact_angle_deg        0
# dtype: int64

# %%
df = pd.read_csv("asset/data.csv")

# %%
df
# Out:
#     x_position  y_position  composition_ratio  potential_V  \
# 0            1           1              0.800        0.986
# 1            1           2              0.817        0.572
# 2            1           3              0.833        0.987
# 3            1           4              0.850        0.779
# 4            1           5              0.867        1.075
# 5            2           1              0.883        0.762
# 6            2           2              0.900        0.262
# 7            2           3              0.917        0.858
# 8            2           4              0.933        0.366
# 9            2           5              0.950        0.842
# 10           3           1              0.967        0.912
# 11           3           2              0.983        0.066
# 12           3           3              1.000        1.170
# 13           3           4              1.017        0.732
# 14           3           5              1.033        0.540
# ...

# %%
df = df.fillna(0) # replace missing with 0

# %%
df
# Out:
#     x_position  y_position  composition_ratio  potential_V  \
# 0            1           1              0.800        0.986
# 1            1           2              0.817        0.572
# 2            1           3              0.833        0.987
# 3            1           4              0.850        0.779
# 4            1           5              0.867        1.075
# 5            2           1              0.883        0.762
# 6            2           2              0.900        0.262
# 7            2           3              0.917        0.858
# 8            2           4              0.933        0.366
# 9            2           5              0.950        0.842
# 10           3           1              0.967        0.912
# 11           3           2              0.983        0.066
# 12           3           3              1.000        1.170
# 13           3           4              1.017        0.732
# 14           3           5              1.033        0.540
# ...

# %% [markdown]
# ## Grouping & Aggregation

# %%
df.groupby('x_position')['potential_V'].mean()
# Out:
# x_position
# 1    0.8798
# 2    0.6180
# 3    0.6840
# 4    0.7240
# 5    0.6492
# 6    0.0000
# Name: potential_V, dtype: float64

# %% [markdown]
# ## Exporting Data

# %%
df.to_csv("asset/processed_data.csv", index=False)

# %% [markdown]
# ## Plotting (built-in)

# %%
df.plot(x='x_position', y='potential_V', kind='scatter')
# Out:
# <Axes: xlabel='x_position', ylabel='potential_V'>
