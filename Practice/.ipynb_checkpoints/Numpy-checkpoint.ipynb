# %%
import numpy as np
list1 = [1,2,3]
#1D array
a = np.array([1, 2, 3, 4])
#2D array
b = np.array([[1, 2], [3, 4]])

# %%
a.shape
# Out:
# (4,)

# %%
b.shape
# Out:
# (2, 2)

# %%
a.ndim
# Out:
# 1

# %%
b.ndim
# Out:
# 2

# %%
a.size
# Out:
# 4

# %%
a.dtype
# Out:
# dtype('int64')

# %%
b.size
# Out:
# 4

# %%
b.dtype
# Out:
# dtype('int64')

# %%
c = np.array([1.4, 2.2, 3.7, 4.2])
c.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Array operation

# %%
a = np.array([10, 20, 30, 40])
b = np.array([1, 2, 3, 4])

# %%
a + b
# Out:
# array([11, 22, 33, 44])

# %%
d = np.array([10, 20, 30 ])
e = np.array([1, 2, 3, 4])

# %%
d + e
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 d + e
#
# ValueError: operands could not be broadcast together with shapes (3,) (4,)

# %%
a / b
# Out:
# array([10., 10., 10., 10.])

# %%
a * b
# Out:
# array([ 10,  40,  90, 160])

# %%
a ** 2
# Out:
# array([ 100,  400,  900, 1600])

# %% [markdown]
# ## math functions

# %%
a
# Out:
# array([10, 20, 30, 40])

# %%
np.mean(a)
# Out:
# np.float64(25.0)

# %%
np.std(a)
# Out:
# np.float64(11.180339887498949)

# %%
np.min(a)
# Out:
# np.int64(10)

# %%
np.max(a)
# Out:
# np.int64(40)

# %%
np.sum(a)
# Out:
# np.int64(100)

# %%
np.median(a)
# Out:
# np.float64(25.0)

# %% [markdown]
# ## Indexing and slicing

# %%
a = np.array([10, 20, 30, 40, 50])

# %%
a[0]
# Out:
# np.int64(10)

# %%
a[-1]
# Out:
# np.int64(50)

# %%
a[1:4]
# Out:
# array([20, 30, 40])

# %%
b = np.array([[1, 2, 3],
              [4, 5, 6]])

# %%
b[0, 1]
# Out:
# np.int64(2)

# %%
b[:, 1]
# Out:
# array([2, 5])

# %% [markdown]
# ## Reshaping and Combining Arrays

# %%
a
# Out:
# array([10, 20, 30, 40, 50])

# %%
a = np.arange(6)

# %%
a
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
a.reshape(2, 3)
# Out:
# array([[0, 1, 2],
#        [3, 4, 5]])

# %%
b = np.array([[1,2,3],[4,5,6]])

# %%
b
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
c = np.concatenate((b, b), axis=0)

# %%
c
# Out:
# array([[1, 2, 3],
#        [4, 5, 6],
#        [1, 2, 3],
#        [4, 5, 6]])

# %%
d = np.concatenate((b, b), axis=1)

# %%
d
# Out:
# array([[1, 2, 3, 1, 2, 3],
#        [4, 5, 6, 4, 5, 6]])

# %% [markdown]
# ## Generating data

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((3,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.arange(0, 10, 2)
# Out:
# array([0, 2, 4, 6, 8])

# %%
np.linspace(0, 1, 5)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %% [markdown]
# ## logical operations

# %%
a = np.array([10, 15, 20, 25, 30])

# %%
a
# Out:
# array([10, 15, 20, 25, 30])

# %%
a[a > 20]
# Out:
# array([25, 30])

# %% [markdown]
# ## Random number

# %%
np.random.rand(3, 3)
# Out:
# array([[0.58766073, 0.17934107, 0.50377866],
#        [0.23520826, 0.35899968, 0.30011816],
#        [0.61368011, 0.67652792, 0.28330975]])

# %%
np.random.randint(0, 10, (2,3))
# Out:
# array([[2, 2, 8],
#        [0, 7, 6]], dtype=int32)
